# %%
import importlib
import Localization
importlib.reload(Localization)
from Localization import *
import os

# %%
localization_tools = Localization_Tools()
hsi_localization = HSI_Localization()

# %%
lcf_file, bil_file, dji_file, output_path, prefix, file_numbers, time_offset = Data_Process_Set(DEF_DATASET_16072025_S1_ROW2=True)

#lcf_file, bil_file, dji_file, output_path, prefix, file_numbers, time_offset = Data_Process_Set()



print(f"file number = {file_numbers} \ntime offset  = {time_offset}")
# Out:
# file number = [4, 5, 6]
# time offset  = 119.265

# %%
#just for safty comment it
hsi_localization.synchronize_DJI_LCF(lcf_file, bil_file, dji_file, output_path, prefix, file_numbers, time_offset )
# Out:
# Starting synchronization pipeline
# Loading LCF: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\combined_navigation_1_to_11.lcf
# Loading BIL_TIMES: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\Combined_navigation_1_11.bil.times
# Filtering prefix: RS_25HeritageWhtLL_Pika IR L+_
# Filtering prefix: RS_25HeritageWhtLL_Pika IR L+_
# Length LCF: 28234
# Length BIL_TIMES: 19777
# Filtering file numbers: in lcf [4, 5, 6]
# Filtering file numbers: in bil_times [4, 5, 6]
# Length LCF after filter: 8529
# Length bil_times after filter: 5972
# fist valur of lcf   =   1436730656.39
# Saved: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row2\HSI_Localization_Synch_Times_LCF.txt
# HSI Time Range: 1436730775.6550002 to 1436730818.3016732
# DJI Time Range: 1436730586.52 to 1436732794.46
# ...

# %%
### use to display points on KML

# %%
#ip_kml = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1\Path_Synch_Data.kml"
#op_kml = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1\Path_Synch_Data_Google_Map.kml"

ip_kml = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2\Path_Synch_Data.kml"
op_kml = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2\Path_Synch_Data_Google_Map.kml"

localization_tools.undersample_kml_points(ip_kml,op_kml)
# Out:
# Total points in original KML: 7841
# Points after sampling: 7841
# Saved new Google-Earth compatible KML:
# D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2\Path_Synch_Data_Google_Map.kml

# %%
# Closed point for time Synchronization used in DJI and HSI

# %%
time_lcf_file=r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2\HSI_Localization_Synch_Times_LCF.txt"
dji_file=r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\01-DJI_Drone_RC4APP_Extracted\DJIFlightRecord_2025-07-16_[16-16-05]\DJIFlightRecord_2025-07-16_[16-16-05].txt"
       
output_path=r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2"

    
localization_tools.find_closest_dji_points(time_lcf_file, dji_file, output_path)
# Out:
# HSI First Point
# Time: 1436732296.88
# Lat : 52.18159002890572
# Lon : -106.5145274557513
#
# Top 5 Closest DJI Points
#            GPSTime   Latitude   Longitude  distance_m  time_difference
# 2341  1.436732e+09  52.181579 -106.514526    1.192825          -120.77
# 2340  1.436732e+09  52.181579 -106.514525    1.198110          -120.67
# 2342  1.436732e+09  52.181579 -106.514526    1.200055          -120.87
# 2344  1.436732e+09  52.181579 -106.514528    1.200219          -121.07
# 2343  1.436732e+09  52.181579 -106.514527    1.200950          -120.97
#
# Saved: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2\Closest_DJI_Points.txt
#            GPSTime   Latitude   Longitude  Altitude_ft    hSpeed  xSpeed  \
# 2341  1.436732e+09  52.181579 -106.514526         65.6  0.894776     0.0
# 2340  1.436732e+09  52.181579 -106.514525         65.6  0.894776     0.0
# ...

# %%
Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row2"
DJI_LCF_Synch_TXT_path = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )

localization_tools.Synch_HSI_DJI_LCF_to_mat(DJI_LCF_Synch_TXT_path, Base_Path)
# Out:
# Loaded TXT (Top 3 rows):
#        GPS_Time  roll_rad  pitch_rad   yaw_rad  longitude_deg  latitude_deg  \
# 0  1.436731e+09  0.006663   0.041020 -1.560144    -106.514536      52.18158
# 1  1.436731e+09  0.006748   0.040794 -1.560001    -106.514536      52.18158
# 2  1.436731e+09  0.006908   0.040539 -1.559753    -106.514536      52.18158
#
#    altitude_m  vel_east_mps  vel_north_mps  satellites  ...  DJI_Longitude  \
# 0        98.0           0.0            0.0         5.0  ...    -106.514536
# 1        98.0           0.0            0.0         5.0  ...    -106.514536
# 2        98.0           0.0            0.0         5.0  ...    -106.514536
#
#    DJI_Altitude_ft  DJI_Pitch  DJI_Roll    DJI_Yaw  DJI_Direction  DJI_hSpeed  \
# 0             98.0       -1.2 -0.522727 -89.940909     263.768174     2.23694
# 1             98.0       -1.2 -0.503249 -89.934416     263.281214     2.23694
# 2             98.0       -1.2 -0.483771 -89.927924     262.794271     2.23694
#
# ...
