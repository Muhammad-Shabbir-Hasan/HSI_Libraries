# %%
import importlib
import Localization
importlib.reload(Localization)
from Localization import *
import os

# %%
localization_tools = Localization_Tools()
hsi_localization = HSI_Localization()

# %% [markdown]
# # Step A:       Closed point for time Synchronization used in DJI and HSI
# ### Step A.1:     Must chenge path for HSI_Localization_Synch_Times_LCF.txt
# ### Step A.2:     Must chenge path for DJIFlightRecord_2025-07-16_[16-16-05].txt
# ### Step A.3:     Output - Must chenge path for output location (1607_S2_Row2)

# %%
time_lcf_file=r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2\HSI_Localization_Synch_Times_LCF.txt"
dji_file=r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\01-DJI_Drone_RC4APP_Extracted\DJIFlightRecord_2025-07-16_[16-16-05]\DJIFlightRecord_2025-07-16_[16-16-05].txt"
       
output_path=r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2"

    
localization_tools.find_closest_dji_points(time_lcf_file, dji_file, output_path)

# %%
# Step B:   Set the time offset and get data from file
lcf_file, bil_file, dji_file, output_path, prefix, file_numbers, time_offset = Data_Process_Set(DEF_DATASET_16072025_S1_ROW4=True)

print(f"file number = {file_numbers} \ntime offset  = {time_offset}")

# %% [markdown]
# # Step C
# ### Step C.1:     It first synch bil.times with lcf
# ### Step C.2:     After synching bil.times and lcf it synch with DJI drone based on offset time
# ### Step C.3:     Output is bil.times synch with lcf (HSI_Localization_Synch_Times_LCF.txt/mat)
# ### Step C.4:     Output is bil.times synch and lcf (C.3)  with DJI path (HSI_Path_Synch_LCF_DJI.txt/mat)
# ### Step C.5:     Output is from LCF and DJI synch file (C.4) it create kml path (Path_Synch_Data.kml)

# %%
#   just for safty comment it
hsi_localization.synchronize_DJI_LCF(lcf_file, bil_file, dji_file, output_path, prefix, file_numbers, time_offset )

# %% [markdown]
# # Step D:       (optional)
# ### Step D.0 :    It is used to reduce kml points to display at google map (upto 10K points)
# ### Step D.1:     Mutst change folder location (1607_S2_Row2) Use to display points on google map
# ### Step D.2:     use to display points on KML

# %%
Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S2_Row2"
ip_kml = os.path.join(Base_Path, "Path_Synch_Data.kml" )
op_kml = os.path.join(Base_Path, "Path_Synch_Data_Google_Map.kml" )


localization_tools.undersample_kml_points(ip_kml,op_kml)

# %% [markdown]
# # Step E:       Data visualization in Matlab/Octave
# ### Step E.1:     Check the Base_Path
# ### Step E.2:     Output is mat file inside base folder (HSI_Path_Synch_LCF_DJI.mat)

# %%
DJI_LCF_Synch_TXT_path = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )

localization_tools.Synch_HSI_DJI_LCF_to_mat(DJI_LCF_Synch_TXT_path, Base_Path)

# %% [markdown]
# # Used to convert plot information exported from QGIS to txt for further process (one time)

# %%
QGIS_Plot_Location_CSV_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\PLot_Locations_QGIS_13N.csv"
Plot_Location_txt_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations"

localization_tools.convert_plot_csv_to_txt(QGIS_Plot_Location_CSV_Path, Plot_Location_txt_Path)
