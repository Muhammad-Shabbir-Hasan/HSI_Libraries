# %%
import importlib

#import HSI.HSI
#importlib.reload(HSI.HSI)

import HSI
importlib.reload(HSI)
from HSI import *

# %%
temp = Temp()

# %%
Folder_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_3007202515m\Resonon"
Output_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\30072025_Combined"

temp.combine_navigation_files(Folder_Path, Output_Path)
# Out:
# Saved LCF: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\30072025_Combined\combined_navigation.lcf
# Saved TIMES: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\30072025_Combined\combined_navigation.bil.times
# Navigation merge complete.

# %%
Folder_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_3007202515m\Resonon\3007_S1_Row4"
Ref_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\RS_25HeritageWhtLL_Pika IR L+_1-radiance_main.bil.hdr"
temp.update_hdr_from_reference(Folder_Path, Ref_Path)
# Out:
# Target HDR: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_3007202515m\Resonon\3007_S1_Row4\combined_cube.bil.hdr
# Reference HDR: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\RS_25HeritageWhtLL_Pika IR L+_1-radiance_main.bil.hdr
# HDR updated successfully.

# %%
cube = Cube()
# Out:
# Cube initialized

# %%
Mat_File_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.mat"


cube.Convert_Mat_to_Cube(Mat_File_Path)
# Out:
# Cube saved: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.bil
# HDR saved : D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.bil.hdr

# %%
Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1"
#Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\1607_S1_Row1"
Output_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_3007202515m\Resonon\S1_Row4"

# %%
# Load Hyperspectral cube with other informations
cube.Load_Cube(Base_Folder)

# Display Hyperspectral bands
cube.Show_Centered_Freq(cube.cube)
#cube_data, bil, times, lcf, kml, hdr = cube.Load_Cube(Base_Folder)

# Display image as RGB at given bands
cube.Show_Image(cube.cube, 50,150,250)
# Out:
# Selected .bil file: combined_cube.bil
#
# Selected .times file: None
#
# Selected .lcf file: None
#
# Selected .kml file: None
#
# Selected .hdr file: combined_cube.bil.hdr
#
#
#
# ✅ Cube loaded
# Cube shape (lines, samples, bands): (5805, 640, 478)
#
#
#
# Total number of spectrum: 478

# %%
mat = Mat()
# Out:
# Mat Object initialized

# %%
# Convert cube data to compress mat file
mat.Convert_Cube_to_Mat(Base_Folder)
# Out:
# Cube initialized
#
#
# Selected .bil file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.bil
#
# Selected .times file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1.bil.times
#
# Selected .lcf file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1.lcf
#
# Selected .kml file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1_path.kml
#
# Selected .hdr file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.bil.hdr
#
#
# ✅ Cube loaded
# ...

# %%
# View mat file plot in RGB at random selected bands
Mat_File_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.mat")
mat.load_and_display_mat(Mat_File_Path)
# Out:
# Loading MAT file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.mat
#
# MAT type: MATLAB v7.3 (HDF5)
#
# Variables in file:
#   hsi
#
# Cube variable: hsi
# Cube shape: (2000, 640, 478)
# Data type: float32
#
# Cube info:
# Lines   : 2000
# Samples : 640
# Bands   : 478
#
# Metadata extracted:
# acquisition time = 2025-07-16T19:48:09.136458Z
# bands = 478
# byte order = 0
# ceiling = 16383
# data type = 12
# direction = logo right
# field of view = 21.7
# flip radiometric calibration = False
# framerate = 140.0
# ground elevation = 0
# header offset = 0
# imager serial number = Pika IR L+-1016
# interleave = bil
# lines = 2000
# sample binning = 1
# samples = 640
# shutter = 4.028
# shutter units = milliseconds
# spectral binning = 1
# target = RS_25HeritageWhtLL
# temperature = 20.0
# ...
