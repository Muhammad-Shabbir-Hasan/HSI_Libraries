# %%
import importlib
import Mosaics
importlib.reload(Mosaics)
import os



DEF_1607_S1R1 = False
DEF_1607_S1R2 = True
DEF_1607_S1R3 = False
DEF_1607_S1R4 = False
DEF_1607_S2R2 = False
DEF_1607_S2R3 = False
DEF_1607_S2R4 = False




if DEF_1607_S1R1:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path


elif DEF_1607_S1R2:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row2"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path

elif DEF_1607_S1R3:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row3"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path

elif DEF_1607_S1R4:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path

elif DEF_1607_S2R2:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path

elif DEF_1607_S2R3:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path

elif DEF_1607_S2R4:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Locations.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    Output_Path = Base_Path


mosaics = Mosaics.Mosaics()
# Out:
# Mat Object initialized

# %%
#print(f"{HSI_DJI_Synch_File_Txt}")

mosaics.Extract_Pixelwise_Geolocation_Pipeline(HSI_DJI_Synch_File_Txt, Wheat_Plot_Locations__File, Cube_Mat_File, Geo_Location_Path, Output_Path )
# Out:
# D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row2\HSI_Path_Synch_LCF_DJI.txt
# Starting HSI Mosaic Pipeline
# Loading plot information...
# Loading hyperspectral cube...
#
# Loading MAT file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row2\combined_cube.mat
#
# MAT type: MATLAB v7.3 (HDF5)
#
# Variables in file:
#   hsi
#
# Cube variable: hsi
# Cube shape: (5972, 640, 478)
# Data type: float32
#
# Cube info:
# Lines   : 5972
# Samples : 640
# Bands   : 478
#
# Metadata extracted:
# bands = 478
# byte order = 0
# data type = 4
# file type = ENVI Standard
# header offset = 0
# interleave = bip
# lines = 5972
# samples = 640
# Finished.
#
# Computing pixel-wise geolocation...
# Computing pixelwise geolocation...
# center pixel = 320.0, IFOV = 0.03390625
# ...
