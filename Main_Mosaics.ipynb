# %%
import importlib
import Mosaics
importlib.reload(Mosaics)
import os


DEF_1607_S1R1 = False
DEF_1607_S1R2 = False
DEF_1607_S1R3 = False
DEF_1607_S1R4 = True
DEF_1607_S2R2 = False
DEF_1607_S2R3 = False
DEF_1607_S2R4 = False



if DEF_1607_S1R1:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )
    
    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S1_R1.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )

    Output_Path = Base_Path


elif DEF_1607_S1R2:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row2"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )

    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S1_R2.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )

    Output_Path = Base_Path

elif DEF_1607_S1R3:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row3"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )

    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S1_R3.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )



    Output_Path = Base_Path

elif DEF_1607_S1R4:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )

    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S1_R4.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )



    Output_Path = Base_Path

elif DEF_1607_S2R2:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )

    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S2_R2.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )



    Output_Path = Base_Path

elif DEF_1607_S2R3:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )

    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S2_R3.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )


    Output_Path = Base_Path

elif DEF_1607_S2R4:
    Base_Path = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row4"
    Wheat_Plot_Locations__File = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_Plots_Locations\Plot_Location_UTM13.txt"
    HSI_DJI_Synch_File_Txt = os.path.join(Base_Path, "HSI_Path_Synch_LCF_DJI.txt" )
    Cube_Mat_File = os.path.join( Base_Path,"combined_cube.mat" )
    Geo_Location_Path = os.path.join( Base_Path,"pixel_geolocation.txt" )

    Mat_file = os.path.join(Base_Path, "pixel_geolocation.mat" )
    tiff_image_path = os.path.join(Base_Path, "1607_S2_R4.tiff" )
    plotwise_jpg_path = os.path.join(Base_Path, "pixel_geolocation_plotwise.jpg" )

    Plot_Base_Folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
    Overall_Combined_Scan_Plotwise = os.path.join( Plot_Base_Folder,"Plotwise_HSI" )


    Output_Path = Base_Path


mosaics = Mosaics.Mosaics()
mosaics_tools = Mosaics.Mosaics_Tools()
plot_mosaic = Mosaics.Plot_Mosaic()
saver = Mosaics.PlotMatSaver()
# Out:
# Mat Object initialized
# Mat Object initialized
# Mat Object initialized
# Mat Object initialized
# Mat Object initialized
# Cube initialized

# %%
# Creating plotwise cube in bil and mat format

base_folder = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\Plotwise_HSI"
cube_root = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined"
sample_hdr = r"D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\Wheat_1607202515m\Resonon\RS_25HeritageWhtLL-1\RS_25HeritageWhtLL_Pika IR L+_1-radiance.bil.hdr"

# %%
import os

pixels_location = plot_mosaic.read_all_plot_files(base_folder)
print(f"plot_files = {pixels_location}")
# Out:
# Final combined shape: (4926544, 7)
# plot_files =          pixel_x  pixel_y   longitude   latitude  class        folder     plot
# 0            330      413 -106.515091  52.181526      1  1607_S1_Row1   plot_1
# 1            331      413 -106.515091  52.181526      1  1607_S1_Row1   plot_1
# 2            332      413 -106.515091  52.181526      1  1607_S1_Row1   plot_1
# 3            333      413 -106.515091  52.181526      1  1607_S1_Row1   plot_1
# 4            334      413 -106.515091  52.181526      1  1607_S1_Row1   plot_1
# ...          ...      ...         ...        ...    ...           ...      ...
# 4926539      635      567 -106.514709  52.181637     99  1607_S1_Row4  plot_99
# 4926540      636      567 -106.514709  52.181637     99  1607_S1_Row4  plot_99
# 4926541      637      567 -106.514709  52.181637     99  1607_S1_Row4  plot_99
# 4926542      638      567 -106.514709  52.181637     99  1607_S1_Row4  plot_99
# ...

# %%
# -----------------------------------------
# Step 1: Extract spectra
# -----------------------------------------
pixels = plot_mosaic.extract_pixel_spectra(pixels_location, cube_root)
# Out:
# Loading cube: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1\combined_cube.mat
# Loading cube : D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1\combined_cube.mat
#
# Loading MAT file: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\1607_S1_Row1\combined_cube.mat
#
# MAT type: MATLAB v7.3 (HDF5)
#
# Variables in file:
#   hsi
#
# Cube variable: hsi
# Cube shape: (5805, 640, 478)
# Data type: float32
#
# Cube info:
# Lines   : 5805
# Samples : 640
# Bands   : 478
#
# Metadata extracted:
# bands = 478
# byte order = 0
# data type = 4
# file type = ENVI Standard
# header offset = 0
# interleave = bip
# lines = 5805
# samples = 640
# Finished.
#
# plot name = plot_1 , 1607_S1_Row1
# plot name = plot_10 , 1607_S1_Row1
# plot name = plot_11 , 1607_S1_Row1
# ...

# %%
#print(f"pixel = {pixels['plot_1'][100]}")
print(f"pixel = {len(pixels['plot_2'])}")
print(f"pixel = {(pixels['plot_1'][1][2][1])}")
# Out:
# pixel = 27021
# pixel = 0.0

# %%
saver.save_all_plots(
    pixels=pixels,
    base_output_path=base_folder
)
# Out:
# Processing plot_1
# Saving MAT: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\Plotwise_HSI\plot_1\plot_1.mat
# Shape: (25137, 478)
# Saved using scipy (MAT v7)
#
# Processing plot_10
# Saving MAT: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\Plotwise_HSI\plot_10\plot_10.mat
# Shape: (20847, 478)
# Saved using scipy (MAT v7)
#
# Processing plot_11
# Saving MAT: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\Plotwise_HSI\plot_11\plot_11.mat
# Shape: (33012, 478)
# Saved using scipy (MAT v7)
#
# Processing plot_12
# Saving MAT: D:\00-Workspace(NB)\00-Workspace(UoR)\00-Data(Field)\2025\01-AAFC(Raju)\01-Processed_Data\16072025_Combined\Plotwise_HSI\plot_12\plot_12.mat
# Shape: (29749, 478)
# Saved using scipy (MAT v7)
#
# Processing plot_13
# ...

# %%
# -----------------------------------------
# Step 2: Compute resolution
# -----------------------------------------
Plot_Res = plot_mosaic.compute_resolution(pixels)
print(f"resolution = {Plot_Res}  ")
# Out:
# plot_1 → dlon:7.629394517039145e-06, dlat:3.8146972585195726e-06
# resolution = {'plot_1': {'res_x': np.float64(7.629394517039145e-06), 'res_y': np.float64(3.8146972585195726e-06), 'min_lon': np.float64(-106.5150909423828), 'max_lon': np.float64(-106.51507568359376), 'min_lat': np.float64(52.18149566650391), 'max_lat': np.float64(52.18152618408203)}}

# %%
    # -----------------------------------------
    # Step 3: Create cube
    # -----------------------------------------
plot_mosaic.create_plotwise_cube(pixels, Plot_Res)
# Out:
# Processing plot_1
# Grid size: 10 3 478
# {'plot_1': array([[[0.        , 0.        , 8.793775  , ..., 0.        ,
#           0.        , 0.        ],
#          [2.3940346 , 2.9827316 , 2.901099  , ..., 0.0989011 ,
#           0.        , 0.        ],
#          [0.        , 2.904943  , 0.        , ..., 0.        ,
#           0.        , 0.        ]],
#
#         [[0.        , 3.952381  , 0.55654764, ..., 0.        ,
#           0.        , 0.        ],
#          [4.441431  , 9.376803  , 5.170225  , ..., 0.25678015,
#           0.        , 0.        ],
#          [2.2748015 , 0.37301588, 1.1011904 , ..., 0.        ,
#           0.        , 0.        ]],
#
#         [[2.2650602 , 0.        , 0.        , ..., 0.        ,
#           0.        , 0.        ],
#          [5.084136  , 8.113038  , 2.3705845 , ..., 0.        ,
#           0.13423249, 0.        ],
#          [0.        , 1.9636679 , 3.486159  , ..., 0.        ,
#           0.        , 0.        ]],
#
#         ...,
#
# ...

# %%
    # -----------------------------------------
    # Step 4: Output paths
    # -----------------------------------------
    name = os.path.splitext(file_name)[0]

    out_dir = os.path.join(base_folder, "plots")

    bil_path = os.path.join(out_dir, name + ".bil")
    hdr_path = os.path.join(out_dir, name + ".hdr")
    mat_path = os.path.join(out_dir, name + ".mat")

    # -----------------------------------------
    # Step 5: Save BIL
    # -----------------------------------------
    plot_mosaic.save_bil(cube, bil_path)

    # -----------------------------------------
    # Step 6: Create HDR
    # -----------------------------------------
    plot_mosaic.create_hdr(sample_hdr, hdr_path, width, height, bands)

    # -----------------------------------------
    # Step 7: Convert to MAT
    # -----------------------------------------
    plot_mosaic.bil_to_mat(bil_path, mat_path)


print("\nAll plots processed successfully.")



#lot_mosaic.generate_plot_cubes(base_folder, cube_root, sample_hdr)

# %%
#print(f"{HSI_DJI_Synch_File_Txt}")

mosaics.Extract_Pixelwise_Geolocation_Pipeline(HSI_DJI_Synch_File_Txt,
                                               Wheat_Plot_Locations__File,
                                                 Cube_Mat_File,
                                                   Geo_Location_Path,
                                                     Output_Path,
                                                     line_start = 0,
                                                      line_end = None )

# %%
### Pixel Geo location to jpg

mosaics_tools.pixel_geolocation_mat_to_jpg(Mat_file,Base_Path)

# %%
### combined HSI_Pseudo image and Geo location to jpg
mosaics_tools.combine_tiff_pixel_geolocation_jpg(tiff_image_path, plotwise_jpg_path, Base_Path)

# %%
# Merging plotwise scan data to single place from all scan
mosaics.merging_plotwise_scan_information_mat(Plot_Base_Folder, Overall_Combined_Scan_Plotwise)
